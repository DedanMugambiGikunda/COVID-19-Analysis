# %%
import pandas as pd

data = pd.read_csv(r"/home/dedan/Desktop/Covid19/Covid Data.csv")

data.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
# 2      2             1    2             2  09/06/2020        1          2
# 3      2             1    1             1  12/06/2020       97          2
# 4      2             1    2             1  21/06/2020       97          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
# 2   55        97         1  ...       2        2             2              2
# 3   53         2         2  ...       2        2             2              2
# 4   68        97         1  ...       2        2             1              2
#
# ...

# %%
data.count()
# Out:
# USMER                   1048575
# MEDICAL_UNIT            1048575
# SEX                     1048575
# PATIENT_TYPE            1048575
# DATE_DIED               1048575
# INTUBED                 1048575
# PNEUMONIA               1048575
# AGE                     1048575
# PREGNANT                1048575
# DIABETES                1048575
# COPD                    1048575
# ASTHMA                  1048575
# INMSUPR                 1048575
# HIPERTENSION            1048575
# OTHER_DISEASE           1048575
# CARDIOVASCULAR          1048575
# OBESITY                 1048575
# RENAL_CHRONIC           1048575
# TOBACCO                 1048575
# CLASIFFICATION_FINAL    1048575
# ICU                     1048575
# dtype: int64

# %%
data.isnull().sum()
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# DATE_DIED               0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# ICU                     0
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
#data.groupby('Region')['confirmed'].sum().sort_values(ascending)

# %%
data.groupby('SEX').sum()
# Out:
#       USMER  MEDICAL_UNIT  PATIENT_TYPE  \
# SEX
# 1    857291       4712492        606790
# 2    854187       4704304        641816
#
#                                              DATE_DIED   INTUBED  PNEUMONIA  \
# SEX
# 1    03/05/202012/06/20209999-99-999999-99-999999-9...  43493191    1833067
# 2    03/06/202009/06/202021/06/20209999-99-999999-9...  39892508    1676336
#
#           AGE  PREGNANT  DIABETES     COPD   ASTHMA  INMSUPR  HIPERTENSION  \
# SEX
# 1    21693123   1402381   1122727  1161725  1149596  1183756       1092441
# 2    22131128  50780567   1169882  1208651  1201966  1226008       1139964
#
#      OTHER_DISEASE  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  \
# SEX
# 1          1247106         1165332  1089104        1162955  1148938
# 2          1306324         1206345  1139302        1203867  1172956
#
#      CLASIFFICATION_FINAL       ICU
# SEX
# 1                 2842796  43505451
# 2                 2720579  39912857

# %%
#Confirmed cases less than 10
data.AGE < 10
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1048570    False
# 1048571    False
# 1048572    False
# 1048573    False
# 1048574    False
# Name: AGE, Length: 1048575, dtype: bool

# %%
#Confirmed cases less than age 10
data[data.AGE < 10]
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 151          1             2    1             2  26/02/2020       99
# 153          1             2    1             2  08/05/2020        1
# 155          1             2    2             2  17/07/2020       99
# 161          1             2    2             2  9999-99-99        2
# 163          1             2    2             2  9999-99-99        2
# ...        ...           ...  ...           ...         ...      ...
# 1048329      2            13    1             2  9999-99-99        2
# 1048342      2            13    2             2  9999-99-99        2
# 1048404      1            13    2             2  9999-99-99        2
# 1048434      1            13    1             1  9999-99-99       97
# 1048527      2            13    2             2  9999-99-99        2
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 151             99    1         2         2  ...       2        2
# ...

# %%
data.groupby('AGE').PREGNANT.sum()
# Out:
# AGE
# 0      209127
# 1      272513
# 2      178720
# 3      134901
# 4      130387
#         ...
# 117       101
# 118       194
# 119         6
# 120       486
# 121         2
# Name: PREGNANT, Length: 121, dtype: int64

# %%
#------#

# %%
#Both genders and how they were affected
data['SEX'].value_counts()
# Out:
# SEX
# 1    525064
# 2    523511
# Name: count, dtype: int64

# %%
#DEATHS BY SEX BAR PLOT
import matplotlib.pyplot as plt
death_by_sex.plot(kind='bar', title="Deaths by Sex")
plt.ylabel("Number of Deaths")
plt.show()

# %%
#AGE BY SEX BOXPLOT
sns.boxplot(x='SEX', y='AGE', data=data)
plt.title('Age Distribution by Sex')
plt.show()

# %%
data['PATIENT_TYPE'].value_counts()
# Out:
# PATIENT_TYPE
# 1    848544
# 2    200031
# Name: count, dtype: int64

# %%
#AGE DISTRIBUTION HISTOGRAM
data['AGE'].hist(bins=30, color='blue', edgecolor='black')
plt.title('Age Distribution of COVID-19 Patients')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#DISTRIBUTIONOF PATIENT TYPE
patient_type_distribution = data['PATIENT_TYPE'].value_counts()
patient_type_distribution.plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title("Patient Type Distribution")
plt.show()

# %%
icu_by_classification = data.groupby('CLASIFFICATION_FINAL')['ICU'].value_counts()

# %%
#CLEANING
#FILLING MISSING VALUES
data['AGE'] = data['AGE'].fillna(data['AGE'].median())

# %%
#REMOVING ROWS WHERE CRITICAL DATA IS MISSING
data_cleaned = data.dropna(subset=['PREGNANT'])
